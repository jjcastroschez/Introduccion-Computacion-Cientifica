# %% [markdown]
# # Detección de olas de calorDada una lista de temperaturas máximas diarias, contar cuántas **olas de calor** ha habido. Una ola de calor es un periodo de **al menos 3 días consecutivos** con la temperatura máxima por encima del umbral (36 ºC en este ejemplo).

# %%
# Temperaturas máximas diarias (ºC) de un mestemperaturas = [28, 31, 33, 35, 37, 38, 36, 34, 32, 30, 29, 31, 36, 38, 39, 41, 40, 37, 35, 33, 31, 29, 30, 32, 34, 36, 37, 38, 39, 36]UMBRAL = 36DIAS_MIN = 3olas = 0dias_olas = 0racha = 0for t in temperaturas:    if t > UMBRAL:        racha = racha + 1        if racha == DIAS_MIN:            olas = olas + 1            dias_olas = dias_olas + DIAS_MIN        elif racha > DIAS_MIN:            dias_olas = dias_olas + 1    else:        racha = 0print(f'Se han detectado {olas} olas de calor.')print(f'Total de días en olas: {dias_olas}.')
