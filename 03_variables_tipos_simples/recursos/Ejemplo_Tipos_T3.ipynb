# %% [markdown]
# # Mi primer experimento con Variables
# En este notebook vamos a probar cómo Python gestiona los tipos de datos de forma dinámica.

# %%
# Definimos una variable con un número entero
numero_alumnos = 25
print(f"Valor: {numero_alumnos} - Tipo: {type(numero_alumnos)}")

# Ahora cambiamos el tipo de la misma variable (Tipado Dinámico)
numero_alumnos = "Veinticinco"
print(f"Valor: {numero_alumnos} - Tipo: {type(numero_alumnos)}")
# Out:
# No se puede iniciar Jupyter. Error al intentar buscar Jupyter: La ejecución de celdas con 'Python 3.13.7' requiere el paquete jupyter y notebook.
#
# Instale "jupyter y notebook" en el entorno de Python.
#
# Comando: "python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U"
#
# Haga clic <a href='https://aka.ms/installJupyterForVSCode'>aquí</a> para obtener más información.

# %% [markdown]
# # Operaciones y Precedencia
# Vamos a calcular el área de un círculo: $Area = \pi \cdot r^2$

# %%
radio = 5.0
# Usamos el operador de potencia **
area = 3.1416 * radio ** 2

print(f"El área del círculo es: {area:.2f}")
# Out:
# El área del círculo es: 78.54
